# %%
# !pip install opencv-python mediapipe numpy pandas
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Collecting mediapipe
#   Downloading mediapipe-0.10.31-py3-none-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting numpy
#   Downloading numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting absl-py~=2.3 (from mediapipe)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting sounddevice~=0.5 (from mediapipe)
#   Downloading sounddevice-0.5.3-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl.metadata (1.6 kB)
# Collecting flatbuffers~=25.9 (from mediapipe)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting CFFI>=1.0 (from sounddevice~=0.5->mediapipe)
#   Downloading cffi-2.0.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniconda/base/envs/mediapipe_env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting pycparser (from CFFI>=1.0->sounddevice~=0.5->mediapipe)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/envs/mediapipe_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 46.6 MB/s  0:00:00 43.0 MB/s eta 0:00:01
# Downloading numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 56.7 MB/s  0:00:00
# Downloading mediapipe-0.10.31-py3-none-macosx_11_0_arm64.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 62.3 MB/s  0:00:00 67.8 MB/s eta 0:00:01
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading sounddevice-0.5.3-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl (108 kB)
# Downloading pandas-2.3.3-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 28.8 MB/s  0:00:00.5 MB/s eta 0:00:01
# Downloading cffi-2.0.0-cp310-cp310-macosx_11_0_arm64.whl (180 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: pytz, flatbuffers, tzdata, pycparser, numpy, absl-py, pandas, opencv-python, CFFI, sounddevice, mediapipe
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [mediapipe] 10/11 [mediapipe]hon]
# Successfully installed CFFI-2.0.0 absl-py-2.3.1 flatbuffers-25.12.19 mediapipe-0.10.31 numpy-2.2.6 opencv-python-4.12.0.88 pandas-2.3.3 pycparser-2.23 pytz-2025.2 sounddevice-0.5.3 tzdata-2025.3

# %%
import cv2
import mediapipe as mp
import csv
import numpy as np
import time

# %%
#new API (https://github.com/google-ai-edge/mediapipe/issues/6192#issuecomment-3684720402)
#https://ai.google.dev/edge/mediapipe/solutions/vision/face_landmarker/python
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# %%
MODEL_PATH = 'face_landmarker.task'
base_options = python.BaseOptions(model_asset_path=MODEL_PATH)

options = vision.FaceLandmarkerOptions(
    base_options=base_options,
    running_mode=vision.RunningMode.VIDEO
)

detector = vision.FaceLandmarker.create_from_options(options)
# Out:
# W0000 00:00:1767290089.080815  170104 face_landmarker_graph.cc:180] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1767290089.175248  170104 gl_context.cc:407] GL version: 2.1 (2.1 Metal - 90.5), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1767290089.181694  170107 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1767290089.194873  170107 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
